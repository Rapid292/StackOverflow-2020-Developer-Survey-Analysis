# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.head()
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %%
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
type(df['Hobbyist'])
# Out:
# pandas.core.series.Series

# %%
df['Hobbyist'][1]
# Out:
# 'Yes'

# %%
df.Hobbyist
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df.Hobbyist[1]
# Out:
# 'Yes'

# %%
df[['Hobbyist', 'Country']]
# Out:
#            Hobbyist             Country
# Respondent
# 1               Yes             Germany
# 2                No      United Kingdom
# 3               Yes  Russian Federation
# 4               Yes             Albania
# 5               Yes       United States
# ...             ...                 ...
# 64858           Yes       United States
# 64867           Yes             Morocco
# 64898           Yes            Viet Nam
# 64925           Yes              Poland
# 65112           Yes               Spain
#
# [64461 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.iloc[0]  #to get rows 
#iloc :access rows by integer location
# Out:
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# DatabaseDesireNextYear                                       Microsoft SQL Server
# ...

# %%
df.iloc[[0, 1]] # to access multiple rows using integer location
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df.iloc[[0, 1], 8]
# Out:
# Respondent
# 1     European Euro
# 2    Pound sterling
# Name: CurrencyDesc, dtype: object

# %%
df.iloc[[0, 1], [8,22,59]]
# Out:
#               CurrencyDesc            MiscTechDesireNextYear YearsCodePro
# Respondent
# 1            European Euro                 .NET Core;Xamarin           27
# 2           Pound sterling  React Native;TensorFlow;Unity 3D            4

# %%
df.loc[3] #access rows by location
# Out:
# MainBranch                                           I code primarily as a hobby
# Hobbyist                                                                     Yes
# Age                                                                          NaN
# Age1stCode                                                                    15
# CompFreq                                                                     NaN
# CompTotal                                                                    NaN
# ConvertedComp                                                                NaN
# Country                                                       Russian Federation
# CurrencyDesc                                                                 NaN
# CurrencySymbol                                                               NaN
# DatabaseDesireNextYear                                                       NaN
# DatabaseWorkedWith                                                           NaN
# ...

# %%
df.loc[[1, 2, 10], ['WorkWeekHrs', 'YearsCode']] #access rows by location
# Out:
#             WorkWeekHrs YearsCode
# Respondent
# 1                  50.0        36
# 2                   NaN         7
# 10                 36.0         8

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Age']
# Out:
# Respondent
# 1         NaN
# 2         NaN
# 3         NaN
# 4        25.0
# 5        31.0
#          ...
# 64858     NaN
# 64867     NaN
# 64898     NaN
# 64925     NaN
# 65112     NaN
# Name: Age, Length: 64461, dtype: float64

# %%
df.loc[1:5, 'Hobbyist':'Employment']
# Out:
#            Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 1               Yes   NaN         13  Monthly        NaN            NaN
# 2                No   NaN         19      NaN        NaN            NaN
# 3               Yes   NaN         15      NaN        NaN            NaN
# 4               Yes  25.0         18      NaN        NaN            NaN
# 5               Yes  31.0         16      NaN        NaN            NaN
#
#                        Country    CurrencyDesc CurrencySymbol  \
# Respondent
# 1                      Germany   European Euro            EUR
# 2               United Kingdom  Pound sterling            GBP
# 3           Russian Federation             NaN            NaN
# 4                      Albania    Albanian lek            ALL
# 5                United States             NaN            NaN
#
#            DatabaseDesireNextYear                         DatabaseWorkedWith  \
# Respondent
# ...

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['SOVisitFreq','QuestionText' ]
# Out:
# 'How frequently would you say you visit Stack Overflow?'

# %%
schema_df.sort_index(inplace=True) #put if want sort in asc (ascending=False)
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
schema_df.loc['ConvertedComp', 'QuestionText']
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and 50 working weeks.'

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 8            United States                                         Python;SQL
# 16          United Kingdom  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 17           United States              C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 18           United States                Bash/Shell/PowerShell;HTML/CSS;Perl
# 19           United States  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                    ...                                                ...
# 65586        United States                                                NaN
# 65589        United States                                                NaN
# 65602        United States                                                NaN
# 65604        United States                                                NaN
# 65617              Germany                                                NaN
#
# ...

# %%
countries = ['United States', 'United Kingdom', 'India', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                       LanguageWorkedWith  \
# Respondent
# 1                  Germany                   C#;HTML/CSS;JavaScript
# 2           United Kingdom                         JavaScript;Swift
# 5            United States                        HTML/CSS;Ruby;SQL
# 6                  Germany                 HTML/CSS;Java;JavaScript
# 7                    India                          C#;HTML/CSS;PHP
# ...                    ...                                      ...
# 62834               Canada                            C;C#;C++;Java
# 62954                India                                      SQL
# 63077        United States  C++;HTML/CSS;Java;JavaScript;Python;SQL
# 64236                India                                      NaN
# 64858        United States                                      NaN
#
#             ConvertedComp
# Respondent
# 1                     NaN
# 2                     NaN
# 5                     NaN
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
filt
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 64858    False
# 64867     True
# 64898    False
# 64925    False
# 65112    False
# Name: LanguageWorkedWith, Length: 64461, dtype: bool

# %%
df.loc[filt, ['Country', 'LanguageWorkedWith', 'ConvertedComp']].head(20)
# Out:
#                        Country  \
# Respondent
# 3           Russian Federation
# 8                United States
# 10              United Kingdom
# 13                 Netherlands
# 15                      France
# 17               United States
# 22                       India
# 26                      Canada
# 27               United States
# 28                       China
# 29                     Ukraine
# 30              United Kingdom
# 32                      Canada
# 36              United Kingdom
# 38                       Italy
# 39              United Kingdom
# 40               United States
# 42               United States
# 44                      Brazil
# 45                      France
#
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 3                                    Objective-C;Python;Swift            NaN
# 8                                                  Python;SQL       116000.0
# ...
