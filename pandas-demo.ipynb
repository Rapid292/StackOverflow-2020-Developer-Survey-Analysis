# %%
import pandas as pd

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='Respondent', na_values=na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.head()
# Out:
#                                                  QuestionText
# Column
# Respondent  Randomized respondent ID number (not in order ...
# MainBranch  Which of the following options best describes ...
# Hobbyist                              Do you code as a hobby?
# Age         What is your age (in years)? If you prefer not...
# Age1stCode  At what age did you write your first line of c...

# %%
df.head(2)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
type(df['Hobbyist'])
# Out:
# pandas.core.series.Series

# %%
df['Hobbyist'][1]
# Out:
# 'Yes'

# %%
df.Hobbyist
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df.Hobbyist[1]
# Out:
# 'Yes'

# %%
df[['Hobbyist', 'Country']]
# Out:
#            Hobbyist             Country
# Respondent
# 1               Yes             Germany
# 2                No      United Kingdom
# 3               Yes  Russian Federation
# 4               Yes             Albania
# 5               Yes       United States
# ...             ...                 ...
# 64858           Yes       United States
# 64867           Yes             Morocco
# 64898           Yes            Viet Nam
# 64925           Yes              Poland
# 65112           Yes               Spain
#
# [64461 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df.iloc[0]  #to get rows 
#iloc :access rows by integer location
# Out:
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# DatabaseDesireNextYear                                       Microsoft SQL Server
# ...

# %%
df.iloc[[0, 1]] # to access multiple rows using integer location
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             CompTotal  ConvertedComp         Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       DevType  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df.iloc[[0, 1], 8]
# Out:
# Respondent
# 1     European Euro
# 2    Pound sterling
# Name: CurrencyDesc, dtype: object

# %%
df.iloc[[0, 1], [8,22,59]]
# Out:
#               CurrencyDesc            MiscTechDesireNextYear YearsCodePro
# Respondent
# 1            European Euro                 .NET Core;Xamarin           27
# 2           Pound sterling  React Native;TensorFlow;Unity 3D            4

# %%
df.loc[3] #access rows by location
# Out:
# MainBranch                                           I code primarily as a hobby
# Hobbyist                                                                     Yes
# Age                                                                          NaN
# Age1stCode                                                                    15
# CompFreq                                                                     NaN
# CompTotal                                                                    NaN
# ConvertedComp                                                                NaN
# Country                                                       Russian Federation
# CurrencyDesc                                                                 NaN
# CurrencySymbol                                                               NaN
# DatabaseDesireNextYear                                                       NaN
# DatabaseWorkedWith                                                           NaN
# ...

# %%
df.loc[[1, 2, 10], ['WorkWeekHrs', 'YearsCode']] #access rows by location
# Out:
#             WorkWeekHrs YearsCode
# Respondent
# 1                  50.0        36
# 2                   NaN         7
# 10                 36.0         8

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Age']
# Out:
# Respondent
# 1         NaN
# 2         NaN
# 3         NaN
# 4        25.0
# 5        31.0
#          ...
# 64858     NaN
# 64867     NaN
# 64898     NaN
# 64925     NaN
# 65112     NaN
# Name: Age, Length: 64461, dtype: float64

# %%
df.loc[1:5, 'Hobbyist':'Employment']
# Out:
#            Hobbyist   Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# Respondent
# 1               Yes   NaN         13  Monthly        NaN            NaN
# 2                No   NaN         19      NaN        NaN            NaN
# 3               Yes   NaN         15      NaN        NaN            NaN
# 4               Yes  25.0         18      NaN        NaN            NaN
# 5               Yes  31.0         16      NaN        NaN            NaN
#
#                        Country    CurrencyDesc CurrencySymbol  \
# Respondent
# 1                      Germany   European Euro            EUR
# 2               United Kingdom  Pound sterling            GBP
# 3           Russian Federation             NaN            NaN
# 4                      Albania    Albanian lek            ALL
# 5                United States             NaN            NaN
#
#            DatabaseDesireNextYear                         DatabaseWorkedWith  \
# Respondent
# ...

# %%
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
schema_df.loc['Hobbyist']
# Out:
# QuestionText    Do you code as a hobby?
# Name: Hobbyist, dtype: object

# %%
schema_df.loc['SOVisitFreq','QuestionText' ]
# Out:
# 'How frequently would you say you visit Stack Overflow?'

# %%
schema_df.sort_index(inplace=True) #put if want sort in asc (ascending=False)
schema_df
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
schema_df.loc['ConvertedComp', 'QuestionText']
# Out:
# 'Salary converted to annual USD salaries using the exchange rate on 2020-02-19, assuming 12 working months and 50 working weeks.'

# %%
high_salary = (df['ConvertedComp'] > 70000)

# %%
df.loc[high_salary, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 8            United States                                         Python;SQL
# 16          United Kingdom  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 17           United States              C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 18           United States                Bash/Shell/PowerShell;HTML/CSS;Perl
# 19           United States  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                    ...                                                ...
# 65586        United States                                                NaN
# 65589        United States                                                NaN
# 65602        United States                                                NaN
# 65604        United States                                                NaN
# 65617              Germany                                                NaN
#
# ...

# %%
countries = ['United States', 'United Kingdom', 'India', 'Germany', 'Canada']
filt = df['Country'].isin(countries)

# %%
df.loc[filt, ['Country', 'LanguageWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                       LanguageWorkedWith  \
# Respondent
# 1                  Germany                   C#;HTML/CSS;JavaScript
# 2           United Kingdom                         JavaScript;Swift
# 5            United States                        HTML/CSS;Ruby;SQL
# 6                  Germany                 HTML/CSS;Java;JavaScript
# 7                    India                          C#;HTML/CSS;PHP
# ...                    ...                                      ...
# 62834               Canada                            C;C#;C++;Java
# 62954                India                                      SQL
# 63077        United States  C++;HTML/CSS;Java;JavaScript;Python;SQL
# 64236                India                                      NaN
# 64858        United States                                      NaN
#
#             ConvertedComp
# Respondent
# 1                     NaN
# 2                     NaN
# 5                     NaN
# ...

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)
filt
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
#          ...
# 64858    False
# 64867     True
# 64898    False
# 64925    False
# 65112    False
# Name: LanguageWorkedWith, Length: 64461, dtype: bool

# %%
df.loc[filt, ['Country', 'LanguageWorkedWith', 'ConvertedComp']].head(20)
# Out:
#                        Country  \
# Respondent
# 3           Russian Federation
# 8                United States
# 10              United Kingdom
# 13                 Netherlands
# 15                      France
# 17               United States
# 22                       India
# 26                      Canada
# 27               United States
# 28                       China
# 29                     Ukraine
# 30              United Kingdom
# 32                      Canada
# 36              United Kingdom
# 38                       Italy
# 39              United Kingdom
# 40               United States
# 42               United States
# 44                      Brazil
# 45                      France
#
#                                            LanguageWorkedWith  ConvertedComp
# Respondent
# 3                                    Objective-C;Python;Swift            NaN
# 8                                                  Python;SQL       116000.0
# ...

# %%
df.rename(columns={'ConvertedComp': 'SalaryUSD'}, inplace=True)
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].map({'Yes': True, 'No': 'False'}) #map don't have inplace arg
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes': True, 'No': 'False'})

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN     True   NaN
# 64867                                                     NaN     True   NaN
# 64898                                                     NaN     True   NaN
# 64925                                                     NaN     True   NaN
# 65112                                                     NaN     True   NaN
#
# ...

# %%
df.sort_values(by=['Country', 'SalaryUSD'],ascending=[True, False], inplace=True)

# %%
df[['Country', 'SalaryUSD']].head(50)  #Sorting
# Out:
#                 Country  SalaryUSD
# Respondent
# 62788       Afghanistan  1000000.0
# 65381       Afghanistan  1000000.0
# 65456       Afghanistan  1000000.0
# 38672       Afghanistan   231192.0
# 28374       Afghanistan   130000.0
# 9839        Afghanistan    23328.0
# 63848       Afghanistan    23328.0
# 51862       Afghanistan    20950.0
# 51509       Afghanistan    20220.0
# 44484       Afghanistan    18660.0
# 15422       Afghanistan    18000.0
# 2932        Afghanistan    16335.0
# 26540       Afghanistan    13992.0
# 57269       Afghanistan    10884.0
# 26775       Afghanistan     8016.0
# 30568       Afghanistan     5448.0
# 30522       Afghanistan     4668.0
# 28811       Afghanistan     4509.0
# 34969       Afghanistan     4356.0
# 26857       Afghanistan     2328.0
# 33878       Afghanistan     1860.0
# 35753       Afghanistan      780.0
# 18049       Afghanistan      109.0
# 35295       Afghanistan        0.0
# 898         Afghanistan        NaN
# ...

# %%
df['SalaryUSD'].nlargest(10)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: SalaryUSD, dtype: float64

# %%
df.nlargest(10, 'SalaryUSD')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5725                           I am a developer by profession    False  26.0
# 54263                          I am a developer by profession     True  29.0
# 43430                          I am a developer by profession     True  33.0
# 59279                          I am a developer by profession     True   NaN
# 46711                          I am a developer by profession     True   NaN
# 123                            I am a developer by profession     True  26.0
# 125         I am not primarily a developer, but I write co...     True  41.0
# 193                            I am a developer by profession     True  29.0
# 665                            I am a developer by profession     True  24.0
# 699         I am not primarily a developer, but I write co...     True  39.0
#
#                       Age1stCode CompFreq     CompTotal  SalaryUSD  \
# Respondent
# ...

# %%
df.nsmallest(10, 'SalaryUSD')
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 35295       I am a developer by profession     True   NaN         13  Monthly
# 47357       I am a developer by profession     True   NaN          5   Weekly
# 6054        I am a developer by profession     True  38.0         15   Yearly
# 27135       I am a developer by profession    False   NaN         16   Yearly
# 60292       I am a developer by profession     True   NaN         12   Yearly
# 38813       I am a developer by profession    False   NaN         18  Monthly
# 8470        I am a developer by profession     True   NaN          5  Monthly
# 41006       I am a developer by profession     True  22.0         17   Yearly
# 15493       I am a developer by profession    False  44.0         17  Monthly
# 57369       I am a developer by profession    False  44.0         18  Monthly
#
#             CompTotal  SalaryUSD      Country        CurrencyDesc  \
# Respondent
# ...

# %%
df.head() #Grouping and Aggregating
# Out:
#                                 MainBranch Hobbyist  Age  \
# Respondent
# 62788       I am a developer by profession     True  NaN
# 65381       I am a developer by profession    False  NaN
# 65456       I am a developer by profession     True  NaN
# 38672       I am a developer by profession    False  NaN
# 28374       I am a developer by profession     True  NaN
#
#                       Age1stCode CompFreq     CompTotal  SalaryUSD  \
# Respondent
# 62788                        NaN   Weekly  8.000000e+06  1000000.0
# 65381                          8   Weekly  8.740000e+09  1000000.0
# 65456       Younger than 5 years   Weekly  5.521171e+09  1000000.0
# 38672                          5  Monthly  1.225000e+06   231192.0
# 28374                          7   Yearly  1.300000e+05   130000.0
#
#                 Country          CurrencyDesc CurrencySymbol  \
# Respondent
# 62788       Afghanistan          Albanian lek            ALL
# ...

# %%
df[['SalaryUSD', 'Country']].head(15)
# Out:
#             SalaryUSD      Country
# Respondent
# 62788       1000000.0  Afghanistan
# 65381       1000000.0  Afghanistan
# 65456       1000000.0  Afghanistan
# 38672        231192.0  Afghanistan
# 28374        130000.0  Afghanistan
# 9839          23328.0  Afghanistan
# 63848         23328.0  Afghanistan
# 51862         20950.0  Afghanistan
# 51509         20220.0  Afghanistan
# 44484         18660.0  Afghanistan
# 15422         18000.0  Afghanistan
# 2932          16335.0  Afghanistan
# 26540         13992.0  Afghanistan
# 57269         10884.0  Afghanistan
# 26775          8016.0  Afghanistan

# %%
df['SalaryUSD'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age               29.0
# CompTotal      63000.0
# SalaryUSD      54049.0
# WorkWeekHrs       40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal     SalaryUSD   WorkWeekHrs
# count  45446.000000   3.482600e+04  3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242  1.037561e+05     40.782174
# std        9.585392            inf  2.268853e+05     17.816383
# min        1.000000   0.000000e+00  0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04  2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04  5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05  9.500000e+04     44.000000
# max      279.000000  1.111111e+247  2.000000e+06    475.000000

# %%
df['SalaryUSD'].count() #Only 34756 answered the SalaryUSd question
# Out:
# 34756

# %%
df['Hobbyist'].describe()
# Out:
# count     64416
# unique        2
# top        True
# freq      50388
# Name: Hobbyist, dtype: object

# %%
df['Hobbyist'].value_counts()
# Out:
# True     50388
# False    14028
# Name: Hobbyist, dtype: int64

# %%
schema_df.loc['Age1stCode', 'QuestionText']
# Out:
# 'At what age did you write your first line of code or program? (e.g., webpage, Hello World, Scratch project)'

# %%
df['Country'].value_counts()
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# North Korea             1
# Marshall Islands        1
# Nauru                   1
# Fiji                    1
# Chad                    1
# Name: Country, Length: 183, dtype: int64

# %%
df['Country'].value_counts(normalize=True) #Percentage Value
# Out:
# United States       0.194609
# India               0.131149
# United Kingdom      0.060807
# Germany             0.060713
# Canada              0.034196
#                       ...
# North Korea         0.000016
# Marshall Islands    0.000016
# Nauru               0.000016
# Fiji                0.000016
# Chad                0.000016
# Name: Country, Length: 183, dtype: float64

# %%
country_grp = df.groupby(['Country'])
country_grp

# %%
country_grp.get_group('India')
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 37655                          I am a developer by profession    False   NaN
# 36976       I am not primarily a developer, but I write co...    False   NaN
# 3332                           I am a developer by profession     True   NaN
# 8457                           I am a developer by profession     True  22.0
# 21351                          I am a developer by profession    False  98.0
# ...                                                       ...      ...   ...
# 54757                                                     NaN     True   NaN
# 55407                                                     NaN     True   NaN
# 62464                                                     NaN     True   NaN
# 62954                                                     NaN     True   NaN
# 64236                                                     NaN     True   NaN
#
# ...

# %%
filt = df['Country'] == 'India'
df.loc[filt].SalaryUSD
# Out:
# Respondent
# 37655    1800000.0
# 36976    1600000.0
# 3332     1000000.0
# 8457     1000000.0
# 21351    1000000.0
#            ...
# 54757          NaN
# 55407          NaN
# 62464          NaN
# 62954          NaN
# 64236          NaN
# Name: SalaryUSD, Length: 8403, dtype: float64

# %%
country_grp['SalaryUSD'].value_counts().loc['India'].head(5)
# Out:
# SalaryUSD
# 5028.0     66
# 16754.0    62
# 8376.0     55
# 8377.0     55
# 2508.0     53
# Name: SalaryUSD, dtype: int64

# %%
country_grp['SalaryUSD'].median().loc['India']
# Out:
# 10056.0

# %%
country_grp['SalaryUSD'].agg(['median', 'mean']).loc['India']
# Out:
# median    10056.000000
# mean      28751.271364
# Name: India, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageWorkedWith']
# Out:
# Respondent
# 37655    C#;Dart;Java;Objective-C;Python;SQL;Swift
# 36976                                          NaN
# 3332                      Go;Java;Python;Scala;SQL
# 8457       Assembly;C;C++;HTML/CSS;Java;Python;SQL
# 21351                        Bash/Shell/PowerShell
#                            ...
# 54757    C;HTML/CSS;Java;JavaScript;PHP;Python;SQL
# 55407                                          NaN
# 62464                                          NaN
# 62954                                          SQL
# 64236                                          NaN
# Name: LanguageWorkedWith, Length: 8403, dtype: object

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 37655     True
# 36976      NaN
# 3332      True
# 8457      True
# 21351    False
#          ...
# 54757     True
# 55407      NaN
# 62464      NaN
# 62954    False
# 64236      NaN
# Name: LanguageWorkedWith, Length: 8403, dtype: object

# %%
df.loc[filt]['LanguageWorkedWith'].str.contains('Python').sum() 
#sum() for Boolean will take True = 1 and False = 0
# Out:
# 2670

# %%
country_grp['LanguageWorkedWith'].str.contains('Python').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-69-cda55dd00399> in <module>
# ----> 1 country_grp['LanguageWorkedWith'].str.contains('Python').sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578
#     579         raise AttributeError(
# --> 580             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     581         )
#     582
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

# %%
country_respondents = df['Country'].value_counts()
country_respondents

# %%
country_uses_python = country_grp['LanguageWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
country_uses_python

# %%
python_df = pd.concat([country_respondents, country_uses_python], axis='columns')
python_df.head(15)

# %%
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageWorkedWith': 'NumKnowsPython'}, inplace=True)

# %%
python_df['PctKnowsPython'] = (python_df['NumKnowsPython']/python_df['NumRespondents']) * 100
python_df

# %%
python_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
python_df.head(50)

# %%
python_df.loc['Pakistan']

# %%
df['YearsCode'].head(10)

# %%
df['YearsCode'].unique() # to get all uniques values

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)

# %%
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()

# %%
df['YearsCode'].median()
